# Togo                              0.79  0.81  0.82  0.84  0.85  0.86  0.87
# Tunisia                           0.95  0.96  0.96  0.96  0.96  0.96  0.96
# Uganda                            0.96  0.98  0.98  0.98  0.99  1.00  1.00
# Zambia                            0.93  0.92  0.93  0.94  0.94  0.97  0.96
# Zimbabwe                          0.97  0.98  0.99  1.00  1.00  1.00  1.00
#
#                                   2017  2018  2019
# Country
# Algeria                           0.94  0.94  0.94
# Angola                            0.86  0.85  0.81
# Benin                             0.84  0.86  0.88
# Botswana                          0.97  0.97  0.97
# Burkina Faso                      0.87  0.89  0.91
# Burundi                           0.93  0.95  0.97
# Cameroon                          0.86  0.87  0.86
# Cape Verde                        0.94  0.93  0.93
# Central African Republic          0.70  0.71  0.71
# Comoros                           0.71  0.71  0.74
# Congo                             0.93  0.93  0.95
# Cote d'Ivoire                     0.80  0.82  0.83
# Chad                              0.99  0.99  1.00
# Democratic Republic of the Congo  0.84  0.85  0.87
# Djibouti                          0.89  0.90  0.91
# Eswatini                          1.00  1.01  1.00
# Egypt                             0.96  0.96  0.96
# Equatorial Guinea                 0.95  0.96  0.97
# Eritrea                           0.99  0.99  1.00
# Ethiopia                          0.86  0.88  0.87
# Gabon                             0.97  0.97  0.98
# Gambia                            1.06  1.05  1.02
# Ghana                             0.98  0.98  0.98
# Guinea                            0.84  0.84  0.82
# Guinea-Bissau                     0.94  0.95  0.96
# Kenya                             0.98  0.98  0.98
# Lesotho                           1.00  1.00  0.98
# Liberia                           0.91  0.90  0.91
# Libya                             0.97  0.97  0.98
# Madagascar                        0.97  0.98  0.98
# Malawi                            1.03  1.03  1.04
# Mali                              0.85  0.86  0.87
# Mauritania                        1.04  1.05  1.05
# Mauritius                         0.99  0.99  0.99
# Morocco                           0.92  0.93  0.94
# Mozambique                        0.88  0.89  0.90
# Namibia                           0.98  0.98  0.98
# Niger                             0.78  0.79  0.82
# Nigeria                           0.90  0.90  0.92
# Rwanda                            1.03  1.03  1.03
# Sao Tome and Principe             0.98  1.01  0.99
# Senegal                           1.02  1.04  1.05
# Seychelles                        1.04  1.04  1.04
# Sierra Leone                      0.84  0.87  0.91
# Somalia                           0.57  0.59  0.60
# South Africa                      0.95  0.95  0.95
# South Sudan                       0.59  0.62  0.64
# Sudan                             0.87  0.89  0.90
# Tanzania                          0.94  0.95  0.96
# Togo                              0.88  0.85  0.90
# Tunisia                           0.96  0.97  0.97
# Uganda                            1.01  1.01  1.01
# Zambia                            0.96  0.98  1.00
# Zimbabwe                          1.00  0.98  0.99

# %%
for year in range(2010,2020):
    fig,ax = plt.subplots(1)
    df[str(year)].plot.barh(ax=ax, figsize=(10,10), title=f"Gender parity index for gross primary graduation ratio {year}")
    ax.set_xlabel('Gender Parity Index')

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].mean())
    
plt.plot(range(2010,2020), vals)
plt.title('Mean')
plt.xlabel('Year')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].median())
    

plt.title('Median')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].std())
    

plt.title('Stdev')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].var())
    

plt.title('Var')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
def iqr(sample):
    return sample.quantile(0.75) - sample.quantile(0.25)

vals = []
for year in range(2010,2020):
    vals.append(iqr(df[str(year)]))
    

plt.title('IQR')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
def siqr(sample):
    return (sample.quantile(0.75) - sample.quantile(0.25))/2

vals = []
for year in range(2010,2020):
    vals.append(siqr(df[str(year)]))
    

plt.title('SIQR')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
def _range(sample):
    return sample.max() - sample.min()

vals = []
for year in range(2010,2020):
    vals.append(_range(df[str(year)]))
    

plt.title('Range')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)
